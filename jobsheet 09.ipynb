# %% [markdown]
# <a href="https://colab.research.google.com/github/narumirr/Algoritma-dan-pemrograman/blob/main/jobsheet%2009.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum 01 - Menggunakan Modul math

# %%
import math

angka = 16
hasil1 = math.sqrt(angka)
hasil2 = math.pow(2, 5)
print("Akar kuadrat dari", angka, "=", hasil1)
print("2 pangkat 5 =", hasil2)
# Out:
# Akar kuadrat dari 16 = 4.0
# 2 pangkat 5 = 32.0

# %% [markdown]
# # Praktikum 02 - Menggunakan from....import...

# %%
from math import sqrt

angka = 25
hasil = sqrt(angka)
print("Akar kuadrat dari", angka, "=", hasil)
# Out:
# Akar kuadrat dari 25 = 5.0

# %% [markdown]
# # Praktikum 03 - Memberi Alias Modul

# %%
import numpy as np

data = np.array([1, 2, 3])
print("Isi array =", data)
# Out:
# Isi array = [1 2 3]

# %% [markdown]
# # Praktikum 04 - Eksplorasi math, random, dan sys

# %%
import math
import random
import sys

hasil1 = math.sqrt(81)
hasil2 = random.randint(1, 10)
versi = sys.version

print("Akar kuadrat 81 =", hasil1)
print("Angka acak 1-10 =", hasil2)
print("Versi Python =", versi)
# Out:
# Akar kuadrat 81 = 9.0
# Angka acak 1-10 = 8
# Versi Python = 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# # Praktikum 05 - Membuat Modul Sendiri

# %%
# %%writefile modulku.py

def halo(nama):
    print(f"Halo, {nama}! Selamat belajar python di Polines")
# Out:
# Overwriting modulku.py

# %%
# %%writefile praktikum09_modul_sendiri.py
import modulku

modulku.halo("Mahasiswa Polines")
# Out:
# Overwriting praktikum09_modul_sendiri.py

# %%
! python praktikum09_modul_sendiri.py
# Out:
# Halo, Mahasiswa Polines! Selamat belajar python di Polines

# %% [markdown]
# # Praktikum 06 - installasi Modul dengan pip

# %%
# !pip install requests
import requests

response = requests.get("https://www.polines.ac.id")
print("Status code:", response.status_code)
# Out:
# ...
# Status code: 403

# %% [markdown]
# # Penugasan 01 - Eksperimen Modul math

# %%
import math

def luas_lingkaran(r):
    luas = math.pi * (r ** 2)
    return luas

r1 = 7
r2 = 10

print(f"Luas lingkaran dengan r = {r1} yaitu: {luas_lingkaran(r1):.2f}")
print(f"Luas lingkaran dengan r = {r2} yaitu: {luas_lingkaran(r2):.2f}")
# Out:
# Luas lingkaran dengan r = 7 yaitu: 153.94
# Luas lingkaran dengan r = 10 yaitu: 314.16

# %% [markdown]
# # Penugasan 02 - Eksperimen dengan Modul random

# %%
import math
import random

print("Angka acak dari 1-100 =")

for i in range(5):
    angka = random.randint(1, 100)
    print(angka)
# Out:
# Angka acak dari 1-100 =
# 59
# 96
# 23
# 82
# 70

# %% [markdown]
# # Penugasan 03 - Modul sys

# %%
import sys

print("--- Versi Python ---")
print("Platform: ", sys.platform)
print("Versi Python: ", sys.version)
# Out:
# --- Versi Python ---
# Platform:  linux
# Versi Python:  3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# # Penugasan 04 - Modul Buatan Sendiri

# %%
# %%writefile konversi.py
def celcius_ke_fahrenheit(c):
    """Mengubah suhu dari Celcius ke Fahrenheit"""
    f = (c * 9/5) + 32
    return f

def fahrenheit_ke_celcius(f):
    """Mengubah suhu dari Fahrenheit ke Celcius"""
    c = (f - 32) * 5/9
    return c
# Out:
# Overwriting konversi.py

# %%
# %%writefile main.py
import konversi

print("=== Program Konversi Suhu ===")

c = 30
f = 100

print(f"{c}ºC = {konversi.celcius_ke_fahrenheit(c):.2f}VF")
print(f"{c}ºF = {konversi.fahrenheit_ke_celcius(f):.2f}ºC")
# Out:
# Overwriting main.py

# %%
! python main.py
# Out:
# === Program Konversi Suhu ===
# 30ºC = 86.00F
# 30ºF = 37.78ºC

# %% [markdown]
# # Penugasan 05 - Installasi Library Pihak Ketiga

# %%
import pandas as pd

data = {
    "NIM" : ["43325002", "43325020", "43325024"],
    "Nama" : ["Amir", "Rafael", "Abi"],
    "Prodi" : ["TRK", "TK", "RE"]
}

df = pd.DataFrame(data)
print("\n==== Data Mahasiswa ====")
print(df)
# Out:
# ==== Data Mahasiswa ====
#         NIM    Nama Prodi
# 0  43325002    Amir   TRK
# 1  43325020  Rafael    TK
# 2  43325024     Abi    RE

# %% [markdown]
# # Penugasan 06 - Studi Kasus Mini

# %%
# %%writefile laporan.py
def tampilkan_laporan(jumlah_soal, skor):
    print("\n=== Laporan Hasil Kuis ===")
    print(f"Jumlah Soal : {jumlah_soal}")
    print(f"Skor Akhir  : {skor}/{jumlah_soal}")
    if skor == jumlah_soal:
        print("Sempurna! Kamu menjawab semua dengan benar.")
    elif skor >= jumlah_soal / 2:
        print("Bagus! Kamu cukup menguasai materi.")
    else:
        print("Tetap semangat, coba lagi ya!")
# Out:
# Overwriting laporan.py

# %%
# %%writefile kuis.py
import random
import laporan

jumlah_soal = 5
skor = 0

print("=== Kuis Penjumlahan Sederhana ===")

for i in range(jumlah_soal):
    a = random.randint(1, 10)
    b = random.randint(1, 10)
    print(f"Soal {i+1}: {a} + {b} = ", end="")
    jawaban = int(input())

    if jawaban == a + b:
        print("✅ Benar!\n")
        skor += 1
    else:
        print(f"❌ Salah! Jawaban yang benar adalah {a + b}\n")

laporan.tampilkan_laporan(jumlah_soal, skor)
# Out:
# Overwriting kuis.py

# %%
! python kuis.py
# Out:
# === Kuis Penjumlahan Sederhana ===
# Soal 1: 5 + 8 = 13
# ✅ Benar!
#
# Soal 2: 4 + 1 = 5
# ✅ Benar!
#
# Soal 3: 7 + 8 = 15
# ✅ Benar!
#
# Soal 4: 2 + 6 = 8
# ✅ Benar!
#
# Soal 5: 6 + 3 = 9
# ✅ Benar!
#
#
# === Laporan Hasil Kuis ===
# Jumlah Soal : 5
# Skor Akhir  : 5/5
# Sempurna! Kamu menjawab semua dengan benar.
